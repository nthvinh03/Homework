# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Data_set\FoodPrice_in_Turkey.csv')

# %%
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df.rename(columns={'Place':'Địa điểm','ProductName':'Tên SP'},inplace=True)
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df['New']='Na'
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price New
# 0  4.4920  Na
# 1  4.5786  Na
# 2  4.7865  Na
# 3  5.1337  Na
# 4  5.5099  Na

# %%
df['Giảm giá']=pd.Series('10%',index=df.index)
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price Giảm giá
# 0  4.4920      10%
# 1  4.5786      10%
# 2  4.7865      10%
# 3  5.1337      10%
# 4  5.5099      10%

# %%
df.insert(9,'Giảm giá 2',pd.Series('12%',index=df.index))

# %%
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price Giảm giá Giảm giá 2
# 0  4.4920      10%        12%
# 1  4.5786      10%        12%
# 2  4.7865      10%        12%
# 3  5.1337      10%        12%
# 4  5.5099      10%        12%

# %%
del df['Giảm giá 2']

# %%
del df['New']

# %%
df.pop('Giảm giá')
# Out:
# 0       10%
# 1       10%
# 2       10%
# 3       10%
# 4       10%
#        ...
# 7376    10%
# 7377    10%
# 7378    10%
# 7379    10%
# 7380    10%
# Name: Giảm giá, Length: 7381, dtype: object

# %%
df.drop('Giảm giá 2',axis=1,inplace=True)

# %%
df.drop(['Year','Price'],axis=1,inplace=True)

# %%
df.iloc[3]
# Out:
# Địa điểm     National Average
# ProductId                  52
# Tên SP          Rice - Retail
# UmId                        5
# UmName                     KG
# Month                      12
# Giảm giá                  10%
# Name: 3, dtype: object

# %%
df.iloc[3:9]
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month Giảm giá
# 3  National Average         52  Rice - Retail     5     KG     12      10%
# 4  National Average         52  Rice - Retail     5     KG      1      10%
# 5  National Average         52  Rice - Retail     5     KG      2      10%
# 6  National Average         52  Rice - Retail     5     KG      3      10%
# 7  National Average         52  Rice - Retail     5     KG      5      10%
# 8  National Average         52  Rice - Retail     5     KG      6      10%

# %%
df.iloc[[3,7,9]]
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month Giảm giá
# 3  National Average         52  Rice - Retail     5     KG     12      10%
# 7  National Average         52  Rice - Retail     5     KG      5      10%
# 9  National Average         52  Rice - Retail     5     KG      7      10%

# %%
df.iloc[:,4]
# Out:
# 0       KG
# 1       KG
# 2       KG
# 3       KG
# 4       KG
#         ..
# 7376    KG
# 7377    KG
# 7378    KG
# 7379    KG
# 7380    KG
# Name: UmName, Length: 7381, dtype: object

# %%
df.iloc[:,3:8]
# Out:
#       UmId UmName  Month Giảm giá
# 0        5     KG      5      10%
# 1        5     KG      6      10%
# 2        5     KG     11      10%
# 3        5     KG     12      10%
# 4        5     KG      1      10%
# ...    ...    ...    ...      ...
# 7376     5     KG      8      10%
# 7377     5     KG      9      10%
# 7378     5     KG     10      10%
# 7379     5     KG     11      10%
# 7380     5     KG     12      10%
#
# [7381 rows x 4 columns]

# %%
df.iloc[3,6]
# Out:
# '10%'

# %%
df.loc[3]
# Out:
# Địa điểm     National Average
# ProductId                  52
# Tên SP          Rice - Retail
# UmId                        5
# UmName                     KG
# Month                      12
# Giảm giá                  10%
# Name: 3, dtype: object

# %%
df.loc[:,'UmName']
# Out:
# 0       KG
# 1       KG
# 2       KG
# 3       KG
# 4       KG
#         ..
# 7376    KG
# 7377    KG
# 7378    KG
# 7379    KG
# 7380    KG
# Name: UmName, Length: 7381, dtype: object

# %%
df.replace('10','Na',inplace=True)

# %%
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month Giảm giá
# 0  National Average         52  Rice - Retail     5     KG      5      10%
# 1  National Average         52  Rice - Retail     5     KG      6      10%
# 2  National Average         52  Rice - Retail     5     KG     11      10%
# 3  National Average         52  Rice - Retail     5     KG     12      10%
# 4  National Average         52  Rice - Retail     5     KG      1      10%

# %%
df['Month'].replace(5,10,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8804\3308298721.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Month'].replace(5,10,inplace=True)

# %%
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month Giảm giá
# 0  National Average         52  Rice - Retail     5     KG     10      10%
# 1  National Average         52  Rice - Retail     5     KG      6      10%
# 2  National Average         52  Rice - Retail     5     KG     11      10%
# 3  National Average         52  Rice - Retail     5     KG     12      10%
# 4  National Average         52  Rice - Retail     5     KG      1      10%
